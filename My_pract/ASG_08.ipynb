# %% [markdown]
# # **DSBDA ASSIGNMENT - 08**
#
# NAME: AKSHADA NATENDRA KAKADE
#
# CLASS : TE COMP A (21CO053)

# %% [markdown]
# **Title of the Assignment: Data Visualization I**
# 1. Use the
# inbuilt dataset 'titanic'. The dataset contains 891 rows and contains
# information about the passengers who boarded the unfortunate Titanic
# ship. Use the Seaborn library to see if we can find any patterns in the
# data.
#
# 2. Write a code to check how the price of the ticket
# (column name: 'fare') for each passenger is distributed by plotting a
# histogram.

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Dataset Integration**

# %%
dataset = sns.load_dataset('titanic')

# %% [markdown]
# **BASIC OPERATIONS**

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
dataset.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
dataset.shape
# Out:
# (891, 15)

# %%
dataset.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %% [markdown]
# **distributional plot**

# %% [markdown]
# **The Dist Plott**

# %%
sns.distplot(dataset['fare'])
# Out:
# <ipython-input-11-8777bd18e486>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'])
# <Axes: xlabel='fare', ylabel='Density'>

# %% [markdown]
# **Removal of Kernal Density line**

# %%
sns.distplot(dataset['fare'], kde=False)
# Out:
# <ipython-input-16-0726c72a01e5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'], kde=False)
# <Axes: xlabel='fare'>

# %% [markdown]
# **HISTOGRAM**

# %%
sns.distplot(dataset['fare'], kde=False, bins=10)
# Out:
# <ipython-input-17-8afd2d5d8da2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'], kde=False, bins=10)
# <Axes: xlabel='fare'>

# %%
sns.histplot(dataset['fare'] , bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x='age', y='fare', data=dataset)

# %%
sns.jointplot(x='age', y='fare', data=dataset, kind='hex')

# %%
sns.boxplot(x='age', y='sex', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %% [markdown]
# **Pair Plot**

# %%
sns.pairplot(dataset)

# %%
dataset = dataset.dropna()

# %%
sns.pairplot(dataset, hue='sex')

# %% [markdown]
# The Rug Plot

# %%
sns.rugplot(dataset['fare'])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# The Bar Plot

# %%
sns.barplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(dataset)
# Out:
# <Axes: >

# %% [markdown]
# The Box Plot

# %%
sns.boxplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age', data=dataset, hue="survived")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# The Violin Plot

# %%
sns.violinplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='sex', y='age', data=dataset, hue='survived', split=True)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# The Strip Plot

# %%
sns.stripplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex', y='age', data=dataset, jitter=True, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %% [markdown]
# The Swarm Plot

# %%
sns.swarmplot(x='sex', y='age', data=dataset)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("/titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
datas=sns.load_dataset('titanic')

# %%
sns.boxplot(x='sex', y='age',data=datas,hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x='sex', y='age',data=datas)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
df.boxplot(

)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
Q1=df['fare'].quantile(0.25)
Q3=df['fare'].quantile(0.75)
IQR=Q3-Q1
LOW_LIMIT = Q1 - 1.5 * IQR
HIG_LIMIT = Q3 + 1.5 * IQR
print(f'Q1={Q1},Q3={Q3},IQR={IQR},LOW_LIMIT={LOW_LIMIT}, HIG_LIMIT={HIG_LIMIT}')
# Out:
# Q1=7.9104,Q3=31.0,IQR=23.0896,LOW_LIMIT=-26.724, HIG_LIMIT=65.6344

# %%
df[(df['fare']< LOW_LIMIT )| (df['fare']>HIG_LIMIT)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 34          0       1    male  28.0      1      0   82.1708        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 846         0       3    male   NaN      8      2   69.5500        S  Third
# 849         1       1  female   NaN      1      0   89.1042        C  First
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
otr=[]
for i in df.fare:
  if i< LOW_LIMIT or i> HIG_LIMIT:
    otr.append(i)

otr
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %%
df[df['fare'] < LOW_LIMIT].index
# Out:
# Index([], dtype='int64')

# %%
HIG_LIMIT
# Out:
# 65.6344

# %%
LOW_LIMIT
# Out:
# -26.724

# %%
df1=df.drop(df[df['fare'] < LOW_LIMIT].index )

# %%
df1
df1.shape
# Out:
# (891, 15)

# %%
df1=df.drop(df[df['fare'] > HIG_LIMIT].index )

# %%
df1.shape
# Out:
# (775, 15)

# %%
df1.boxplot()
# Out:
# <Axes: >

# %%
ndf=df[df['fare'] <50]

# %%
ndf.shape
# Out:
# (715, 15)

# %%
ndf.boxplot()
# Out:
# <Axes: >

# %%
ndf=df[df['age'] >60]
ndf
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
ndf.boxplot()
# Out:
# <Axes: >

# %%
notr=[]
for i in ndf.fare:
  if i< LOW_LIMIT or i> HIG_LIMIT:
    otr.append(i)

notr
# Out:
# []

# %%
otr=[]
for i in ndf.age:
  if i< LOW_LIMIT or i> HIG_LIMIT:
    otr.append(i)

otr
# Out:
# [66.0, 71.0, 70.5, 71.0, 80.0, 70.0, 70.0, 74.0]

# %%
ndf.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# practical- 10 practice

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/Iris1.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.barplot(x='PetalLengthCm',y='epalLengthCm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-af7a86413b69> in <cell line: 1>()
# ----> 1 sns.barplot(x='PetalLengthCm',y='epalLengthCm')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338         estimator = "size"
#    2339
# -> 2340     p = _CategoricalAggPlotter(
#    2341         data=data,
#    2342         variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ...

# %%
sns.kdeplot(df.PetalLengthCm)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
ndf['age'].skew()
# Out:
# 1.232354215607908
